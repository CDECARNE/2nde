# %% [markdown]
# # TP1 - Initiation Python

# %% [markdown]
# ## 1. Programmer

# %% [markdown]
# Programmer, c'est créer des programmes (suite d'ordres donnés à l'ordinateur). Un ordinateur sans programme ne sait rien faire.
#
# Il existe différents langages qui permettent de programmer un ordinateur. Cette année, nous allons apprendre les bases de la programmation en utilisant un langage nommé Python.

# %% [markdown]
# ## 2. Premiers pas

# %% [markdown]
# Pour éxécuter une cellule, appuyez sur la touche `shift-enter` ou bien cliquez sur le bouton **play** de la barre d'icônes.
#
# <span style='color:blue'>**Application 1 :**</span>
#
# *Exécuter la cellule ci-dessous*

# %%
2+2

# %% [markdown]
# #### Explication :
# La cellule effectue le calcul demandé

# %% [markdown]
# <span style='color:blue'>**Application 2 :**</span>
#
# *Exécuter la cellule ci-dessous*

# %%
print("Hello World")

# %% [markdown]
# #### Explications :
#
# - l'utilisation du mot clé ***print*** permet de réaliser un affichage
# - les parenthèses () après la commande ***print*** sont utilisées pour contenir ce que vous voulez afficher.
# - un texte est délimité par des guillemets " ou parfois '

# %% [markdown]
# <span style='color:blue'>**Application 3 :**</span>
#
# *Exécuter le programme obtenu précédemment (Partie 4)*

# %%
X= float ( input ("X="))
X = X*6
X = X+10
X = X/2
print (X)

# %% [markdown]
# ## 3. Les variables

# %% [markdown]
# Elles sont un moyen de nommer les informations pour une utilisation dans un programme.
# - Les variables permettent de stocker des valeurs.
# - Chaque variable a un nom. Un exemple de nom de variable que nous utiliserons est <B>monNombre</B>.
# - Pour stocker de l'information dans une variable, nous écrivons une commande en utilisant le signe égal (=) dans la manière suivante :

# %%
monNombre = 13
print(monNombre+1)

# %% [markdown]
# L'instruction suivante est très utile. Elle permet d'ajouter 1 au contenu de la variable a.

# %%
a=3
a=a+1
print(a)

# %% [markdown]
# #### Explications :
# Sur un plan mathématique, cette égalité n'a pas de sens. En informatique au contraire,
# - la machine va commencer par calculer le membre de droite. Ici **a+1** est évalué à 3+1=4
# - Ce résultat est ensuite stocké dans la variable **a**.
#
# Donc au final, **a** contient bien la valeur 4.

# %% [markdown]
# ### Attention aux majuscules !
#
# Regardez l'exemple suivant en éxécutant la cellule :

# %%
a=2
print(A) # la casse (distinction entre majuscules et minuscules) est prise en compte

# %% [markdown]
# #### Explications :
# Le message d'erreur, bien qu'en anglais, est très explicite. Il faut prendre le temps de les étudier afin de comprendre vos erreurs lorsqu'elles surviennent.
#
# La variable nommée **A** n'est pas définie. En effet, la variable que nous avons créée s'appelle **a** en minuscule.
#
# Vous remarquerez que le message noté en italique dans le programme n'a pas été pris en compte dans ce programme : c'est le "#" qui le permet. On n'a alors qu'un "commentaire".

# %% [markdown]
# ## 4. Les différents types de variables

# %% [markdown]
# Les variables ne contiennent pas forcément des nombres, elles peuvent aussi abriter du texte, on parle alors de chaine de caractères.

# %%
ma_chaine="bonjour"
autre_chaine="tout le monde"
print(ma_chaine,autre_chaine)

# %% [markdown]
# Vous remarquerez au passage que l'instruction **print** peut afficher plusieurs choses à condition de les séparer par des virgules.
#
# Il y a encore bien d'autres objets que l'on peut mettre dans des variables. En voici quelques exemples, mais il en existe d'autres encore.
#
# - *int* : entiers (ex : -2 ; 5)
# - *float* : décimal (ex : -2.0 ; 2e6=2000000.0)
# - *str* : chaîne de caractère (ex : 'Bonjour' ; "Autre exemple" ; "2+3" ; "5")
# - *bool* : Booléen : Vrai ou Faux. (ex : 2==3, False, 3<4)
# - *list* : Tableau ou liste (ex : [1,'toto', 2.0] ; [[1,2],[3,4]])

# %%
chaine="Je suis une chaîne de caractère"
print("chaine est de type",type(chaine))
nombre=3.14
print(nombre, "est de type",type(nombre))

# %% [markdown]
# Comme vous pouvez le voir Python devine tout seul le type des variables. Il est inutile de lui préciser par avance. Cela est extrèmement pratique.

# %% [markdown]
# ## <span style='color:blue'>**Exercice 1 :**</span>
#
# Exécuter le programme ci-dessous pour différentes valeurs de N.
#
# _Remarque : N**2 signifie N au carré_

# %%
N= float ( input ("N="))
P=N+1
T=P*N
S=T-N**2
print (S)

# %% [markdown]
# Quelle conjecture peut-on faire sur S ?
#
# *Vous répondrez en double cliquant dans la cellule ci-dessous*

# %% [markdown]
# Réponse :
#
# Démonstration :

# %% [markdown]
# ## <span style='color:blue'>**Exercice 2 :**</span>
#
# Jean débute en programmation avec Python. Son professeur lui demande de faire un programme inversant le contenu de deux variables. Jean propose le programme ci-après, malheureusement celui-ci ne fonctionne pas.

# %%
a = 7
b = 2
a = b
b = a
print(a)
print(b)

# %% [markdown]
# 1. Expliquer pourquoi le programme de Jean ne fonctionne pas :
#
# Réponse :

# %% [markdown]
# 2. Modifier le programme pour que la valeur des deux variables a et b soient inversées.

# %% [markdown]
# ## <span style='color:blue'>**Exercice 3 :**</span>
#
# Compléter le programme ci-dessous afin qu'il affiche les coordonnées du milieu de deux points A(xA;yA) et B(xB;yB) situés dans un repère orthonormé.

# %%
xA= float ( input ("xA="))
yA= float ( input ("yA="))
xB= float ( input ("xB="))
yB= float ( input ("yB="))
print("les coordonnées du milieu sont",...,...)

# %% [markdown]
# *Vérifier le programme avec l'exemple de la leçon (CHAPITRE 1) où A a pour coordonnées (−1;3,5) et B a pour coordonnées (2;−1,5)*
